# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.ny.gov","V1l1F58oEE8H1XfoqElKC4EWG")

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.ny.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("d6dy-3h7r", limit=87882)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#             county inspection_grade          inspection_date  \
# 0           Albany                A  2020-05-18T00:00:00.000
# 1           Albany                A  2020-10-22T00:00:00.000
# 2           Albany                C  2020-05-13T00:00:00.000
# 3           Albany                A  2020-10-29T00:00:00.000
# 4           Albany                C  2020-06-04T00:00:00.000
# ...            ...              ...                      ...
# 87877        Wayne                C  2020-10-22T00:00:00.000
# 87878  Westchester                A  2020-07-30T00:00:00.000
# 87879  Westchester                A  2020-06-16T00:00:00.000
# 87880     Tompkins                B  2020-05-05T00:00:00.000
# 87881  Westchester                A  2020-11-23T00:00:00.000
#
#                         owner_name               trade_name  \
# 0                  1095 LOUDON INC      BOGHT CORNERS MOBIL
# 1      ALTAMONT COUNTRY VALUES INC           ALTAMONT AGWAY
# 2                 HISTORY HILL INC      LARK CENTRAL MARKET
# 3       JOHN AND MARYS GROCERY LLC       DELMAR MARKETPLACE
# 4                 MADISON MART INC             MADISON MART
# ...                            ...                      ...
# 87877               FASTRAC EG LLC  FASTRAC EG 203 - WOLCOT
# 87878           LWIN FAMILY CO LLC  HISSHO SUSHI@STOP&SHOP#
# 87879             V&D FOOD&GAS INC                   V&D BP
# 87880          DANDY MINI MART INC       DANDY MINI MART 47
# 87881               CVS ALBANY LLC      CVS PHARMACY #10503
#
#                      street           city statecode zipcode  \
# 0          1095 LOUDON ROAD         COHOES        NY   12047
# 1      106 PROSPECT TERRACE       ALTAMONT        NY   12009
# 2               218 LARK ST         ALBANY        NY   12210
# 3         406 KENWOOD AVE #         DELMAR        NY   12054
# 4           145 MADISON AVE         ALBANY        NY   12202
# ...                     ...            ...       ...     ...
# 87877  5666 WHISKEY HILL RD        WOLCOTT        NY   14590
# 87878   610 WHITE PLAINS RD      TARRYTOWN        NY   10591
# 87879         24 MARBLE AVE  PLEASANTVILLE        NY   10570
# 87880     781 FALL CREEK RD      FREEVILLE        NY   13068
# 87881     20 TARRYTOWN RD #   WHITE PLAINS        NY   10607
#
#                                          geocoded_column  \
# 0      {'latitude': '42.783249', 'longitude': '-73.74...
# 1      {'latitude': '42.701659', 'longitude': '-74.03...
# 2      {'latitude': '42.655577', 'longitude': '-73.76...
# 3      {'latitude': '42.622386', 'longitude': '-73.83...
# 4      {'latitude': '42.64629', 'longitude': '-73.756...
# ...                                                  ...
# 87877  {'latitude': '43.208291', 'longitude': '-76.81...
# 87878  {'latitude': '41.061597', 'longitude': '-73.83...
# 87879  {'latitude': '41.13221', 'longitude': '-73.791...
# 87880  {'latitude': '42.54911', 'longitude': '-76.294...
# 87881  {'latitude': '41.037393', 'longitude': '-73.78...
#
#       :@computed_region_yamh_8v7k :@computed_region_wbg7_3whc  \
# 0                             834                        1176
# 1                             832                        1142
# 2                             814                          47
# 3                             837                        1180
# 4                             814                          39
# ...                           ...                         ...
# 87877                         638                        1658
# 87878                         974                        1347
# 87879                         963                        1336
# 87880                         712                         622
# 87881                         949                        1440
#
#       :@computed_region_kjdx_g34t deficiency_number  \
# 0                            2030               NaN
# 1                            2030               NaN
# 2                            2030               09C
# 3                            2030               NaN
# 4                            2030               12A
# ...                           ...               ...
# 87877                         631               10C
# 87878                        2185               NaN
# 87879                        2185               NaN
# 87880                        2181               15A
# 87881                        2185               NaN
#
#                                   deficiency_description
# 0                                                    NaN
# 1                                                    NaN
# 2      - Universal restroom facility lacks a lid for ...
# 3                                                    NaN
# 4      - Two bags of sugar in the second floor storag...
# ...                                                  ...
# 87877  - Drive thru window service area floor has an ...
# 87878                                                NaN
# 87879                                                NaN
# 87880  - Retail area cappuccino hopper has a moderate...
# 87881                                                NaN
#
# [87882 rows x 15 columns]

# %%
# Imports
from pymongo import MongoClient
import pymongo

# Load csv dataset
data = results_df

# Connect to MongoDB
client =  MongoClient("mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test")
db = client['DAB_DATABASES']
collection = db['Restaurant_inspection_data']
data.reset_index(inplace=True)
data_dict = data.to_dict("records")

# Insert collection
collection.insert_many(data_dict)
