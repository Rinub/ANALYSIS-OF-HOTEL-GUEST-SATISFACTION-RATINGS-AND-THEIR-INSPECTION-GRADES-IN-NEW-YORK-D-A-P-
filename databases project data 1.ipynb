# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", "V1l1F58oEE8H1XfoqElKC4EWG")

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("pitm-atqc", limit=12017)
        

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
print(results_df)
# Out:
#       objectid                                globalid  \
# 0          100    c4b3155b-31a0-4e95-846f-fce09f245437
# 1         1000    753495d8-4429-43e5-85a3-dcf6230ef749
# 2        10000  {3842B5C5-EF04-41A4-8216-D6EA627DCE5E}
# 3        10001  {C212A0FC-C115-4425-8F95-931B12C5F86A}
# 4        10002  {DA48265D-7730-416F-8E1C-EBC8C8ACE2C2}
# ...        ...                                     ...
# 12012     9935  {EFB5780D-1AB1-4937-8F96-E0B54ADF17FF}
# 12013     9936  {176916A4-DF65-4BB7-86F2-C14E01930C90}
# 12014     9937  {54DFE56C-848E-4839-8E8C-7A90B1846B3D}
# 12015     9938  {A50A8AD6-157D-4AB2-803D-5BE0E76E3164}
# 12016     9939  {F015B9B9-5B86-4FEE-8F12-91E609D05016}
#
#       seating_interest_sidewalk                    restaurant_name  \
# 0                      sidewalk  Pomp and Circumstance Hospitality
# 1                          both                          Charm Kao
# 2                   openstreets                   SAKE BAR HAGI 46
# 3                   openstreets                        Yum yum too
# 4                   openstreets                  Xochil Pizza Corp
# ...                         ...                                ...
# 12012               openstreets                     Dim sum palace
# 12013                   roadway                Nomad Cafe & Eatery
# 12014               openstreets                        Shabulixius
# 12015                   roadway            Don Giovanni ristorante
# 12016                      both                        Shabulixius
#
#                          legal_business_name  \
# 0      Pomp and Circumstance Hospitality LLC
# 1                        193 Schemerhorn INC
# 2                        HAMA NEW YORK, INC.
# 3                                Boythaicorp
# 4                          Xochil Pizza Corp
# ...                                      ...
# 12012                     Dim sum Palace inc
# 12013                Nomad cafe & eatery inc
# 12014                        K&T Kitchen LLC
# 12015                   Marilyn 18 rest corp
# 12016                        K&T Kitchen LLC
#
#                        doing_business_as_dba bulding_number            street  \
# 0      Pomp and Circumstance Hospitality LLC            577    Lorimer Street
# 1                                  Charm Kao            193  Schermerhorn St.
# 2                           SAKE BAR HAGI 46            358    W. 46TH STREET
# 3                                Boythaicorp            662              9ave
# 4                          Xochil Pizza Corp           4632        5th Avenue
# ...                                      ...            ...               ...
# 12012                     Dim sum Palace inc            334     W 46th street
# 12013                    Nomad cafe & eatery          67-14        Forest ave
# 12014                            Shabulixius          39-32    Bell Boulevard
# 12015                don Giovanni ristorante            358           west 44
# 12016                        K&T Kitchen LLC          39-32    Bell Boulevard
#
#          borough    zip  ... community_board council_district census_tract  \
# 0       Brooklyn  11211  ...               1               34          501
# 1       Brooklyn  11201  ...               2               33           37
# 2      Manhattan  10036  ...               4                3          121
# 3      Manhattan  10036  ...               4                3          127
# 4       Brooklyn  11220  ...               7               38           80
# ...          ...    ...  ...             ...              ...          ...
# 12012  Manhattan  10036  ...               4                3          121
# 12013     Queens  11385  ...               5               30          585
# 12014     Queens  11361  ...              11               19         1123
# 12015  Manhattan  10036  ...             NaN              NaN          NaN
# 12016     Queens  11361  ...              11               19         1123
#
#            bin         bbl                                               nta  \
# 0      3068653  3027560028                                 East Williamsburg
# 1      3000493  3001640041  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
# 2      1025025  1010360057                                           Clinton
# 3      1025038  1010370001                                           Clinton
# 4          NaN         NaN                                  Sunset Park West
# ...        ...         ...                                               ...
# 12012  1025018  1010360047                                           Clinton
# 12013  4083342  4034820034                                         Ridgewood
# 12014  4137551  4062370022                             Bayside-Bayside Hills
# 12015      NaN         NaN                                               NaN
# 12016  4137551  4062370022                             Bayside-Bayside Hills
#
#       roadway_dimensions_length roadway_dimensions_width  \
# 0                           NaN                      NaN
# 1                            24                        8
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 12012                       NaN                      NaN
# 12013                        16                        5
# 12014                       NaN                      NaN
# 12015                        33                        8
# 12016                         8                        4
#
#       roadway_dimensions_area landmarkdistrict_terms
# 0                         NaN                    NaN
# 1                         192                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 12012                     NaN                    NaN
# 12013                      80                    NaN
# 12014                     NaN                    NaN
# 12015                     264                    NaN
# 12016                      32                    NaN
#
# [12017 rows x 35 columns]

# %%
# Imports
from pymongo import MongoClient
import pymongo

# Load csv dataset
data = results_df

# Connect to MongoDB
client =  MongoClient("mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test")
db = client['DAB_DATABASES']
collection = db['Street_Restaurant_Features']
data.reset_index(inplace=True)
data_dict = data.to_dict("records")

# Insert collection
collection.insert_many(data_dict)
