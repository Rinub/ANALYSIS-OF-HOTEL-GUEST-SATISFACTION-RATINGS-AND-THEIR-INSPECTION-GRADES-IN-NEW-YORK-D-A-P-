# %%
import pandas as pd
import numpy as np # scientific computi
import seaborn as sns # statistical ploting
import matplotlib.pyplot as plt
# %matplotlib inline
import math # besic math functions

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# Create an engine instance

#alchemyEngine   = create_engine('postgresql+psycopg2://postgres:Rinish@21@127.0.0.1:5432/hotel_data', pool_recycle=3600);

 # Connect to PostgreSQL server

#dbConnection    = alchemyEngine.connect();

 

# Read data from PostgreSQL database table and load into a DataFrame instance

#data_1       = pds.read_sql("select * from \"StudentScores\"", dbConnection);

#data_2       = pds.read_sql("select * from \"StudentScores\"", dbConnection);
 

#pds.set_option('display.expand_frame_repr', False);

 

# Print the DataFrame

#print(data_1);
#print(data_2);
 

# Close the database connection

#dbConnection.close();

# %%
data_1=pd.read_csv(r'R:\project\data_1.csv')
data_2=pd.read_csv(r'R:\project\data_2.csv')

# %%
data_1.head(2)
# Out:
#    sidewalk_dimensions_area   latitude  longitude  roadway_dimensions_area  \
# 0                     135.0  40.714264 -73.949416                    210.0
# 1                     100.0  40.689107 -73.986352                    192.0
#
#   seating_interest_sidewalk                    restaurant_name  \
# 0                  sidewalk  Pomp and Circumstance Hospitality
# 1                      both                          Charm Kao
#
#                      legal_business_name            street    county  zipcode  \
# 0  Pomp and Circumstance Hospitality LLC    Lorimer Street  Brooklyn    11211
# 1                    193 Schemerhorn INC  Schermerhorn St.  Brooklyn    11201
#
#   approved_for_sidewalk_seating approved_for_roadway_seating qualify_alcohol  \
# 0                           yes                           no             yes
# 1                           yes                          yes              no
#
#   sla_license_type       time_of_submission
# 0               OP  2020-06-19T11:04:00.000
# 1               OP  2020-06-19T14:35:00.000

# %%
data_2.rename(columns = {'owner_name':'legal_business_name'}, inplace = True)
#sr_f.rename(columns = {'longitude_new':'longitude'}, inplace = True)
#sr_f.rename(columns = {'zipcode_new':'zipcode'}, inplace = True)
#ir.rename(columns = {'trade_name':'restaurant_name'}, inplace = True)
#ir.rename(columns = {'trade_name':'restaurant_name'}, inplace = True)
data_2.head(2)
# Out:
#      county inspection_grade          inspection_date legal_business_name  \
# 0  New York                C  2020-02-05T00:00:00.000        7-ELEVEN INC
# 1  New York                C  2020-02-05T00:00:00.000        7-ELEVEN INC
#
#                trade_name      city  zipcode   latitude  longitude
# 0  7 ELEVEN STORE #35630J  NEW YORK    10001  40.746712 -73.997438
# 1  7 ELEVEN STORE #35630J  NEW YORK    10001  40.746712 -73.997438

# %%
data1_fin=data_1.drop(["time_of_submission","county","street"],axis=1)

data2_fin=data_2.drop(["inspection_date","city",],axis=1)

# %%
data1_fin.head(1)
# Out:
#    sidewalk_dimensions_area   latitude  longitude  roadway_dimensions_area  \
# 0                     135.0  40.714264 -73.949416                    210.0
#
#   seating_interest_sidewalk                    restaurant_name  \
# 0                  sidewalk  Pomp and Circumstance Hospitality
#
#                      legal_business_name  zipcode  \
# 0  Pomp and Circumstance Hospitality LLC    11211
#
#   approved_for_sidewalk_seating approved_for_roadway_seating qualify_alcohol  \
# 0                           yes                           no             yes
#
#   sla_license_type
# 0               OP

# %%
data2_fin.head(1)
# Out:
#      county inspection_grade legal_business_name              trade_name  \
# 0  New York                C        7-ELEVEN INC  7 ELEVEN STORE #35630J
#
#    zipcode   latitude  longitude
# 0    10001  40.746712 -73.997438

# %%
mrg_data_1 = data2_fin.merge(data1_fin, how = 'inner', on = ['latitude','zipcode'])

# %%
mrg_data_1
# Out:
#        county inspection_grade        legal_business_name_x  \
# 0    New York                A  EAST SIDE DAIRY MAKOLET INC
# 1    New York                A                MAZEL TOV INC
# 2    New York                A  NEW HONG FA SEA PRODUCE INC
# 3    New York                A               CVS ALBANY LLC
# 4    New York                B  SILVER STAR ENTERPRISES INC
# ..        ...              ...                          ...
# 411    Queens                C        METRO CONVENIENCE INC
# 412    Queens                C        METRO CONVENIENCE INC
# 413    Queens                A               MOMMY SHOP INC
# 414    Queens                A         NORDOMI #2 DELI CORP
# 415    Queens                A        OASIS BAGEL CAFE CORP
#
#                   trade_name  zipcode   latitude  longitude_x  \
# 0    EAST SIDE DAIRY MAKOLET    10002  40.714581   -73.982051
# 1            MOSHE BAKE SHOP    10002  40.714581   -73.982051
# 2      NEW HONG FA SEA PRDCE    10002  40.718117   -73.991984
# 3        CVS/PHARMACY #10828    10003  40.729732   -73.990660
# 4    FINE FOOD DELI&CONV STR    10010  40.738381   -73.980530
# ..                       ...      ...        ...          ...
# 411        METRO CONVENIENCE    11377  40.746223   -73.914998
# 412        METRO CONVENIENCE    11377  40.746223   -73.914998
# 413               MOMMY SHOP    11385  40.700353   -73.904214
# 414          NORDOMI #2 DELI    11435  40.702658   -73.813105
# 415         OASIS BAGEL CAFE    11693  40.585447   -73.817743
#
#      sidewalk_dimensions_area  longitude_y  roadway_dimensions_area  \
# 0                       304.0   -73.982083                    200.0
# 1                       304.0   -73.982083                    200.0
# 2                       240.0   -73.991973                    160.0
# 3                       126.0   -73.984871                    280.0
# 4                      1035.0   -73.983466                    280.0
# ..                        ...          ...                      ...
# 411                     760.5   -73.915081                    416.0
# 412                     384.0   -73.915081                    408.0
# 413                      54.0   -73.905453                    192.0
# 414                     120.0   -73.809279                    100.0
# 415                     162.0   -73.817729                    144.0
#
#     seating_interest_sidewalk                 restaurant_name  \
# 0                    sidewalk         El Castillo De Jagua II
# 1                    sidewalk         El Castillo De Jagua II
# 2                     roadway                      ZEST RAMEN
# 3                        both   Veniero's Pasticceria & Caffe
# 4                        both                         Molly's
# ..                        ...                             ...
# 411                   roadway                    P J Horgan's
# 412                      both                  P. J. Horgan's
# 413                      both  La Flor Del Paraiso Restaurant
# 414                  sidewalk         Vina Del Mar Restaurant
# 415                      both              Oasis bagel cafe g
#
#                         legal_business_name_y approved_for_sidewalk_seating  \
# 0                        521 Restaurant Corp.                           yes
# 1                        521 Restaurant Corp.                           yes
# 2                       ZEST HOSPITALITY INC.                            no
# 3                             A. Veniero Inc.                           yes
# 4                               inishowen Inc                           yes
# ..                                        ...                           ...
# 411                    4902 Skillman Cafe LLC                            no
# 412                    4902 Skillman Cafe LLC                           yes
# 413            La Flor Del Paraiso Restaurant                           yes
# 414  Vina Del Mar Restaurant Salvadoreno Corp                           yes
# 415                     Oasis bagel cafe Corp                           yes
#
#     approved_for_roadway_seating qualify_alcohol sla_license_type
# 0                             no              no               OP
# 1                             no              no               OP
# 2                            yes             yes               OP
# 3                            yes             yes               OP
# 4                            yes             yes               OP
# ..                           ...             ...              ...
# 411                          yes             yes               OP
# 412                          yes             yes               OP
# 413                          yes             yes               EB
# 414                           no              no               OP
# 415                          yes              no               OP
#
# [416 rows x 17 columns]

# %%
mrg_data_1.duplicated().sum()
# Out:
# 319

# %%
mrg_fnl_1= mrg_data_1.drop_duplicates()

# %%
mrg_fnl_1
# Out:
#        county inspection_grade        legal_business_name_x  \
# 0    New York                A  EAST SIDE DAIRY MAKOLET INC
# 1    New York                A                MAZEL TOV INC
# 2    New York                A  NEW HONG FA SEA PRODUCE INC
# 3    New York                A               CVS ALBANY LLC
# 4    New York                B  SILVER STAR ENTERPRISES INC
# ..        ...              ...                          ...
# 391    Queens                C        METRO CONVENIENCE INC
# 392    Queens                C        METRO CONVENIENCE INC
# 413    Queens                A               MOMMY SHOP INC
# 414    Queens                A         NORDOMI #2 DELI CORP
# 415    Queens                A        OASIS BAGEL CAFE CORP
#
#                   trade_name  zipcode   latitude  longitude_x  \
# 0    EAST SIDE DAIRY MAKOLET    10002  40.714581   -73.982051
# 1            MOSHE BAKE SHOP    10002  40.714581   -73.982051
# 2      NEW HONG FA SEA PRDCE    10002  40.718117   -73.991984
# 3        CVS/PHARMACY #10828    10003  40.729732   -73.990660
# 4    FINE FOOD DELI&CONV STR    10010  40.738381   -73.980530
# ..                       ...      ...        ...          ...
# 391        METRO CONVENIENCE    11377  40.746223   -73.914998
# 392        METRO CONVENIENCE    11377  40.746223   -73.914998
# 413               MOMMY SHOP    11385  40.700353   -73.904214
# 414          NORDOMI #2 DELI    11435  40.702658   -73.813105
# 415         OASIS BAGEL CAFE    11693  40.585447   -73.817743
#
#      sidewalk_dimensions_area  longitude_y  roadway_dimensions_area  \
# 0                       304.0   -73.982083                    200.0
# 1                       304.0   -73.982083                    200.0
# 2                       240.0   -73.991973                    160.0
# 3                       126.0   -73.984871                    280.0
# 4                      1035.0   -73.983466                    280.0
# ..                        ...          ...                      ...
# 391                     760.5   -73.915081                    416.0
# 392                     384.0   -73.915081                    408.0
# 413                      54.0   -73.905453                    192.0
# 414                     120.0   -73.809279                    100.0
# 415                     162.0   -73.817729                    144.0
#
#     seating_interest_sidewalk                 restaurant_name  \
# 0                    sidewalk         El Castillo De Jagua II
# 1                    sidewalk         El Castillo De Jagua II
# 2                     roadway                      ZEST RAMEN
# 3                        both   Veniero's Pasticceria & Caffe
# 4                        both                         Molly's
# ..                        ...                             ...
# 391                   roadway                    P J Horgan's
# 392                      both                  P. J. Horgan's
# 413                      both  La Flor Del Paraiso Restaurant
# 414                  sidewalk         Vina Del Mar Restaurant
# 415                      both              Oasis bagel cafe g
#
#                         legal_business_name_y approved_for_sidewalk_seating  \
# 0                        521 Restaurant Corp.                           yes
# 1                        521 Restaurant Corp.                           yes
# 2                       ZEST HOSPITALITY INC.                            no
# 3                             A. Veniero Inc.                           yes
# 4                               inishowen Inc                           yes
# ..                                        ...                           ...
# 391                    4902 Skillman Cafe LLC                            no
# 392                    4902 Skillman Cafe LLC                           yes
# 413            La Flor Del Paraiso Restaurant                           yes
# 414  Vina Del Mar Restaurant Salvadoreno Corp                           yes
# 415                     Oasis bagel cafe Corp                           yes
#
#     approved_for_roadway_seating qualify_alcohol sla_license_type
# 0                             no              no               OP
# 1                             no              no               OP
# 2                            yes             yes               OP
# 3                            yes             yes               OP
# 4                            yes             yes               OP
# ..                           ...             ...              ...
# 391                          yes             yes               OP
# 392                          yes             yes               OP
# 413                          yes             yes               EB
# 414                           no              no               OP
# 415                          yes              no               OP
#
# [97 rows x 17 columns]

# %%
#sr_f.zipcode.unique()
unique_county = len(pd.unique(mrg_fnl_1['county']))
unique_county
# Out:
# 5

# %%
mrg_fnl_1.county.unique()
# Out:
# array(['New York', 'Richmond', 'Bronx', 'Queens', 'Kings'], dtype=object)

# %%
mrg_fnl_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 0 to 415
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   county                         97 non-null     object
#  1   inspection_grade               97 non-null     object
#  2   legal_business_name_x          97 non-null     object
#  3   trade_name                     97 non-null     object
#  4   zipcode                        97 non-null     int64
#  5   latitude                       97 non-null     float64
#  6   longitude_x                    97 non-null     float64
#  7   sidewalk_dimensions_area       97 non-null     float64
#  8   longitude_y                    97 non-null     float64
#  9   roadway_dimensions_area        97 non-null     float64
#  10  seating_interest_sidewalk      97 non-null     object
#  11  restaurant_name                97 non-null     object
#  12  legal_business_name_y          97 non-null     object
#  13  approved_for_sidewalk_seating  97 non-null     object
#  14  approved_for_roadway_seating   97 non-null     object
#  15  qualify_alcohol                97 non-null     object
#  16  sla_license_type               97 non-null     object
# dtypes: float64(5), int64(1), object(11)
# memory usage: 13.6+ KB

# %%
mrg_fnl_1
# Out:
#        county inspection_grade        legal_business_name_x  \
# 0    New York                A  EAST SIDE DAIRY MAKOLET INC
# 1    New York                A                MAZEL TOV INC
# 2    New York                A  NEW HONG FA SEA PRODUCE INC
# 3    New York                A               CVS ALBANY LLC
# 4    New York                B  SILVER STAR ENTERPRISES INC
# ..        ...              ...                          ...
# 391    Queens                C        METRO CONVENIENCE INC
# 392    Queens                C        METRO CONVENIENCE INC
# 413    Queens                A               MOMMY SHOP INC
# 414    Queens                A         NORDOMI #2 DELI CORP
# 415    Queens                A        OASIS BAGEL CAFE CORP
#
#                   trade_name  zipcode   latitude  longitude_x  \
# 0    EAST SIDE DAIRY MAKOLET    10002  40.714581   -73.982051
# 1            MOSHE BAKE SHOP    10002  40.714581   -73.982051
# 2      NEW HONG FA SEA PRDCE    10002  40.718117   -73.991984
# 3        CVS/PHARMACY #10828    10003  40.729732   -73.990660
# 4    FINE FOOD DELI&CONV STR    10010  40.738381   -73.980530
# ..                       ...      ...        ...          ...
# 391        METRO CONVENIENCE    11377  40.746223   -73.914998
# 392        METRO CONVENIENCE    11377  40.746223   -73.914998
# 413               MOMMY SHOP    11385  40.700353   -73.904214
# 414          NORDOMI #2 DELI    11435  40.702658   -73.813105
# 415         OASIS BAGEL CAFE    11693  40.585447   -73.817743
#
#      sidewalk_dimensions_area  longitude_y  roadway_dimensions_area  \
# 0                       304.0   -73.982083                    200.0
# 1                       304.0   -73.982083                    200.0
# 2                       240.0   -73.991973                    160.0
# 3                       126.0   -73.984871                    280.0
# 4                      1035.0   -73.983466                    280.0
# ..                        ...          ...                      ...
# 391                     760.5   -73.915081                    416.0
# 392                     384.0   -73.915081                    408.0
# 413                      54.0   -73.905453                    192.0
# 414                     120.0   -73.809279                    100.0
# 415                     162.0   -73.817729                    144.0
#
#     seating_interest_sidewalk                 restaurant_name  \
# 0                    sidewalk         El Castillo De Jagua II
# 1                    sidewalk         El Castillo De Jagua II
# 2                     roadway                      ZEST RAMEN
# 3                        both   Veniero's Pasticceria & Caffe
# 4                        both                         Molly's
# ..                        ...                             ...
# 391                   roadway                    P J Horgan's
# 392                      both                  P. J. Horgan's
# 413                      both  La Flor Del Paraiso Restaurant
# 414                  sidewalk         Vina Del Mar Restaurant
# 415                      both              Oasis bagel cafe g
#
#                         legal_business_name_y approved_for_sidewalk_seating  \
# 0                        521 Restaurant Corp.                           yes
# 1                        521 Restaurant Corp.                           yes
# 2                       ZEST HOSPITALITY INC.                            no
# 3                             A. Veniero Inc.                           yes
# 4                               inishowen Inc                           yes
# ..                                        ...                           ...
# 391                    4902 Skillman Cafe LLC                            no
# 392                    4902 Skillman Cafe LLC                           yes
# 413            La Flor Del Paraiso Restaurant                           yes
# 414  Vina Del Mar Restaurant Salvadoreno Corp                           yes
# 415                     Oasis bagel cafe Corp                           yes
#
#     approved_for_roadway_seating qualify_alcohol sla_license_type
# 0                             no              no               OP
# 1                             no              no               OP
# 2                            yes             yes               OP
# 3                            yes             yes               OP
# 4                            yes             yes               OP
# ..                           ...             ...              ...
# 391                          yes             yes               OP
# 392                          yes             yes               OP
# 413                          yes             yes               EB
# 414                           no              no               OP
# 415                          yes              no               OP
#
# [97 rows x 17 columns]

# %%
mrg_fnl_1.to_csv(r'R:\project\mrg_fnl_1.csv', index=False)

# %%
mrg_fnl_1.duplicated().sum()
# Out:
# 0

# %%
#-------------------------------------------------------------------------------------------------------

mrg_data_2 = data2_fin.merge(data1_fin, how = 'inner', on = ['legal_business_name'])

# %%
mrg_data_2
# Out:
#      county inspection_grade          legal_business_name  \
# 0  New York                A             ALLEVA DAIRY INC
# 1  Rockland                A        STARBUCKS CORPORATION
# 2    Queens                A      AMERICAN STAR DELI CORP
# 3    Queens                A      AMERICAN STAR DELI CORP
# 4     Kings                A        CLEMENTINE BAKERY LLC
# 5     Kings                A        CLEMENTINE BAKERY LLC
# 6    Queens                A  A & L DELI MEAT MARKET CORP
#
#                 trade_name  zipcode_x  latitude_x  longitude_x  \
# 0             ALLEVA DAIRY      10013   40.719289   -73.997203
# 1           TEAVANA #28470      10954   41.095415   -74.016365
# 2  AMERICAN STAR DELI CORP      11101   40.753990   -73.935357
# 3  AMERICAN STAR DELI CORP      11101   40.753990   -73.935357
# 4        CLEMENTINE BAKERY      11238   40.687415   -73.959713
# 5        CLEMENTINE BAKERY      11238   40.687415   -73.959713
# 6   A & L DELI MEAT MARKET      11368   40.753043   -73.865227
#
#    sidewalk_dimensions_area  latitude_y  longitude_y  roadway_dimensions_area  \
# 0                    1120.0   40.719292   -73.997172                    560.0
# 1                     290.0   40.743570   -73.976709                    216.0
# 2                     884.0   40.754234   -73.935789                    240.0
# 3                     884.0   40.754234   -73.935789                    200.0
# 4                    1116.5   40.687528   -73.959723                    616.0
# 5                     675.0   40.828741   -73.880172                    292.0
# 6                     721.0   40.753043   -73.865242                    824.0
#
#   seating_interest_sidewalk         restaurant_name  zipcode_y  \
# 0                      both        ALLEVA DAIRY INC      10013
# 1                  sidewalk               STARBUCKS      10016
# 2                  sidewalk      AMERICAN STAR DELI      11101
# 3                      both      AMERICAN STAR DELI      11101
# 4                   roadway       CLEMENTINE BAKERY      11238
# 5                  sidewalk       CLEMENTINE BAKERY      11238
# 6                      both  A&L DELI & MEAT MARKET      11368
#
#   approved_for_sidewalk_seating approved_for_roadway_seating qualify_alcohol  \
# 0                           yes                          yes             yes
# 1                           yes                           no              no
# 2                           yes                           no              no
# 3                           yes                          yes              no
# 4                            no                          yes              no
# 5                           yes                           no              no
# 6                           yes                          yes             yes
#
#   sla_license_type
# 0               OP
# 1               OP
# 2               OP
# 3               OP
# 4               OP
# 5               OP
# 6               RW

# %%
mrg_data_2.duplicated().sum()
# Out:
# 0

# %%
mrg_fnl_2= mrg_data_2.drop_duplicates()

# %%
mrg_fnl_2
# Out:
#      county inspection_grade          legal_business_name  \
# 0  New York                A             ALLEVA DAIRY INC
# 1  Rockland                A        STARBUCKS CORPORATION
# 2    Queens                A      AMERICAN STAR DELI CORP
# 3    Queens                A      AMERICAN STAR DELI CORP
# 4     Kings                A        CLEMENTINE BAKERY LLC
# 5     Kings                A        CLEMENTINE BAKERY LLC
# 6    Queens                A  A & L DELI MEAT MARKET CORP
#
#                 trade_name  zipcode_x  latitude_x  longitude_x  \
# 0             ALLEVA DAIRY      10013   40.719289   -73.997203
# 1           TEAVANA #28470      10954   41.095415   -74.016365
# 2  AMERICAN STAR DELI CORP      11101   40.753990   -73.935357
# 3  AMERICAN STAR DELI CORP      11101   40.753990   -73.935357
# 4        CLEMENTINE BAKERY      11238   40.687415   -73.959713
# 5        CLEMENTINE BAKERY      11238   40.687415   -73.959713
# 6   A & L DELI MEAT MARKET      11368   40.753043   -73.865227
#
#    sidewalk_dimensions_area  latitude_y  longitude_y  roadway_dimensions_area  \
# 0                    1120.0   40.719292   -73.997172                    560.0
# 1                     290.0   40.743570   -73.976709                    216.0
# 2                     884.0   40.754234   -73.935789                    240.0
# 3                     884.0   40.754234   -73.935789                    200.0
# 4                    1116.5   40.687528   -73.959723                    616.0
# 5                     675.0   40.828741   -73.880172                    292.0
# 6                     721.0   40.753043   -73.865242                    824.0
#
#   seating_interest_sidewalk         restaurant_name  zipcode_y  \
# 0                      both        ALLEVA DAIRY INC      10013
# 1                  sidewalk               STARBUCKS      10016
# 2                  sidewalk      AMERICAN STAR DELI      11101
# 3                      both      AMERICAN STAR DELI      11101
# 4                   roadway       CLEMENTINE BAKERY      11238
# 5                  sidewalk       CLEMENTINE BAKERY      11238
# 6                      both  A&L DELI & MEAT MARKET      11368
#
#   approved_for_sidewalk_seating approved_for_roadway_seating qualify_alcohol  \
# 0                           yes                          yes             yes
# 1                           yes                           no              no
# 2                           yes                           no              no
# 3                           yes                          yes              no
# 4                            no                          yes              no
# 5                           yes                           no              no
# 6                           yes                          yes             yes
#
#   sla_license_type
# 0               OP
# 1               OP
# 2               OP
# 3               OP
# 4               OP
# 5               OP
# 6               RW

# %%
#---------------------------------------------------------------------

mrg_data_3 = data2_fin.merge(data1_fin, how = 'inner', on = ['latitude'])

# %%
mrg_data_3.duplicated().sum()
# Out:
# 2713

# %%
mrg_fnl_3= mrg_data_3.drop_duplicates()

# %%
mrg_fnl_3
# Out:
#         county inspection_grade         legal_business_name_x  \
# 0     New York                A      300 8TH AVENUE FOOD CORP
# 1     New York                A     243 W 34TH ST RETAIL CORP
# 2     New York                A     243 W 34TH ST RETAIL CORP
# 3     New York                A   EAST SIDE DAIRY MAKOLET INC
# 4     New York                A                 MAZEL TOV INC
# ...        ...              ...                           ...
# 3433    Nassau                A                 SATSANG 4 INC
# 3434   Suffolk                A  165 TROPICA MINI MARKET CORP
# 3435   Suffolk                A       EAST END MARKETING CORP
# 3436   Suffolk                A                 STAR DELI INC
# 3437   Suffolk                A                 STAR DELI INC
#
#                    trade_name  zipcode_x   latitude  longitude_x  \
# 0          CHELSEA FINE FOODS      10001  40.746652   -73.997479
# 1      7 ELEVEN STORE #35895A      10001  40.751658   -73.992195
# 2      7 ELEVEN STORE #35895A      10001  40.751658   -73.992195
# 3     EAST SIDE DAIRY MAKOLET      10002  40.714581   -73.982051
# 4             MOSHE BAKE SHOP      10002  40.714581   -73.982051
# ...                       ...        ...        ...          ...
# 3433   7 ELEVEN STORE #34257B      11804  40.763388   -73.453904
# 3434  165 TROPICA MINI MARKET      11934  40.800556   -72.784215
# 3435         VALERO FOOD MART      11940  40.800306   -72.770829
# 3436                STAR DELI      11951  40.762302   -72.858641
# 3437                STAR DELI      11951  40.762302   -72.858641
#
#       sidewalk_dimensions_area  longitude_y  roadway_dimensions_area  \
# 0                        357.0   -73.893218                    168.0
# 1                        180.0   -73.855529                    168.0
# 2                        504.0   -73.973815                    428.0
# 3                        304.0   -73.982083                    200.0
# 4                        304.0   -73.982083                    200.0
# ...                        ...          ...                      ...
# 3433                     120.0   -73.814282                    160.0
# 3434                     500.0   -73.965615                    480.0
# 3435                     284.5   -73.954667                    464.0
# 3436                     112.0   -73.871129                    120.0
# 3437                     112.0   -73.871129                    128.0
#
#      seating_interest_sidewalk           restaurant_name  \
# 0                         both  HIMALAYAN YAK RESTAURANT
# 1                         both            El gallo negro
# 2                     sidewalk       Wok 43rd Street LLC
# 3                     sidewalk   El Castillo De Jagua II
# 4                     sidewalk   El Castillo De Jagua II
# ...                        ...                       ...
# 3433                      both            Jeunju Sikdang
# 3434                  sidewalk               DOMIZIA INC
# 3435                   roadway                   CANTINA
# 3436                  sidewalk           Cafe y Algo Mas
# 3437                      both           Cafe y Algo Mas
#
#      legal_business_name_y  zipcode_y approved_for_sidewalk_seating  \
# 0      NEPALI KITCHEN INC.      11372                           yes
# 1           La mexican inc      11368                           yes
# 2      Wok 43rd Street LLC      10017                           yes
# 3     521 Restaurant Corp.      10002                           yes
# 4     521 Restaurant Corp.      10002                           yes
# ...                    ...        ...                           ...
# 3433  Jeun Ju Sik Dang Inc      11354                           yes
# 3434           DOMIZIA INC      10025                           yes
# 3435  ACP 111 ST REST CORP      10026                            no
# 3436  Cafe y Algo Mas, Inc      11369                           yes
# 3437  Cafe y Algo Mas, Inc      11369                           yes
#
#      approved_for_roadway_seating qualify_alcohol sla_license_type
# 0                             yes             yes               OP
# 1                             yes             yes               OP
# 2                              no              no               OP
# 3                              no              no               OP
# 4                              no              no               OP
# ...                           ...             ...              ...
# 3433                          yes             yes               RW
# 3434                           no              no               OP
# 3435                          yes             yes               OP
# 3436                           no              no               OP
# 3437                          yes              no               OP
#
# [725 rows x 18 columns]

# %%
unique_county = len(pd.unique(mrg_fnl_3['county']))
unique_county
# Out:
# 7

# %%
mrg_data_1=mrg_fnl_1.drop(["latitude","legal_business_name_y","longitude_x","longitude_y",],axis=1)
mrg_data_2=mrg_fnl_2.drop(["latitude_y","latitude_x","longitude_x","longitude_y","zipcode_y"],axis=1)
mrg_data_3=mrg_fnl_3.drop(["legal_business_name_x","latitude","longitude_x","longitude_y","zipcode_y"],axis=1)

# %%
mrg_data_1.columns
# rename 
#sr_f.rename(columns = {'longitude_new':'longitude'}, inplace = True)
# Out:
# Index(['county', 'inspection_grade', 'legal_business_name_x', 'trade_name',
#        'zipcode', 'sidewalk_dimensions_area', 'roadway_dimensions_area',
#        'seating_interest_sidewalk', 'restaurant_name',
#        'approved_for_sidewalk_seating', 'approved_for_roadway_seating',
#        'qualify_alcohol', 'sla_license_type'],
#       dtype='object')

# %%
mrg_data_2.head()
# Out:
#      county inspection_grade      legal_business_name  \
# 0  New York                A         ALLEVA DAIRY INC
# 1  Rockland                A    STARBUCKS CORPORATION
# 2    Queens                A  AMERICAN STAR DELI CORP
# 3    Queens                A  AMERICAN STAR DELI CORP
# 4     Kings                A    CLEMENTINE BAKERY LLC
#
#                 trade_name  zipcode_x  sidewalk_dimensions_area  \
# 0             ALLEVA DAIRY      10013                    1120.0
# 1           TEAVANA #28470      10954                     290.0
# 2  AMERICAN STAR DELI CORP      11101                     884.0
# 3  AMERICAN STAR DELI CORP      11101                     884.0
# 4        CLEMENTINE BAKERY      11238                    1116.5
#
#    roadway_dimensions_area seating_interest_sidewalk     restaurant_name  \
# 0                    560.0                      both    ALLEVA DAIRY INC
# 1                    216.0                  sidewalk           STARBUCKS
# 2                    240.0                  sidewalk  AMERICAN STAR DELI
# 3                    200.0                      both  AMERICAN STAR DELI
# 4                    616.0                   roadway   CLEMENTINE BAKERY
#
#   approved_for_sidewalk_seating approved_for_roadway_seating qualify_alcohol  \
# 0                           yes                          yes             yes
# 1                           yes                           no              no
# 2                           yes                           no              no
# 3                           yes                          yes              no
# 4                            no                          yes              no
#
#   sla_license_type
# 0               OP
# 1               OP
# 2               OP
# 3               OP
# 4               OP

# %%
mrg_data_3.columns
# Out:
# Index(['county', 'inspection_grade', 'trade_name', 'zipcode_x',
#        'sidewalk_dimensions_area', 'roadway_dimensions_area',
#        'seating_interest_sidewalk', 'restaurant_name', 'legal_business_name_y',
#        'approved_for_sidewalk_seating', 'approved_for_roadway_seating',
#        'qualify_alcohol', 'sla_license_type'],
#       dtype='object')

# %%
mrg_data_1.rename(columns = {'legal_business_name_x':'legal_business_name'}, inplace = True)
mrg_data_2.rename(columns = {'zipcode_x':'zipcode'}, inplace = True)
mrg_data_3.rename(columns = {'zipcode_x':'zipcode'}, inplace = True)
mrg_data_3.rename(columns = {'legal_business_name_y':'legal_business_name'}, inplace = True)

# %%
mrg_data_1.columns
# Out:
# Index(['county', 'inspection_grade', 'legal_business_name', 'trade_name',
#        'zipcode', 'sidewalk_dimensions_area', 'roadway_dimensions_area',
#        'seating_interest_sidewalk', 'restaurant_name',
#        'approved_for_sidewalk_seating', 'approved_for_roadway_seating',
#        'qualify_alcohol', 'sla_license_type'],
#       dtype='object')

# %%
mrg_data_2.columns
# Out:
# Index(['county', 'inspection_grade', 'legal_business_name', 'trade_name',
#        'zipcode', 'sidewalk_dimensions_area', 'roadway_dimensions_area',
#        'seating_interest_sidewalk', 'restaurant_name',
#        'approved_for_sidewalk_seating', 'approved_for_roadway_seating',
#        'qualify_alcohol', 'sla_license_type'],
#       dtype='object')

# %%
mrg_data_3.columns
# Out:
# Index(['county', 'inspection_grade', 'trade_name', 'zipcode',
#        'sidewalk_dimensions_area', 'roadway_dimensions_area',
#        'seating_interest_sidewalk', 'restaurant_name', 'legal_business_name',
#        'approved_for_sidewalk_seating', 'approved_for_roadway_seating',
#        'qualify_alcohol', 'sla_license_type'],
#       dtype='object')

# %%
# rearrange columns in dataframerestaurant_name
mrg_data_1_final = mrg_data_1[['zipcode','county','legal_business_name','seating_interest_sidewalk','approved_for_sidewalk_seating','approved_for_roadway_seating','sidewalk_dimensions_area','roadway_dimensions_area','qualify_alcohol','sla_license_type','inspection_grade']]
mrg_data_2_final = mrg_data_2[['zipcode','county','legal_business_name','seating_interest_sidewalk','approved_for_sidewalk_seating','approved_for_roadway_seating','sidewalk_dimensions_area','roadway_dimensions_area','qualify_alcohol','sla_license_type','inspection_grade']]
mrg_data_3_final = mrg_data_3[['zipcode','county','legal_business_name','seating_interest_sidewalk','approved_for_sidewalk_seating','approved_for_roadway_seating','sidewalk_dimensions_area','roadway_dimensions_area','qualify_alcohol','sla_license_type','inspection_grade']]

# %%
mrg_data_3_final.head()
# Out:
#    zipcode    county   legal_business_name seating_interest_sidewalk  \
# 0    10001  New York   NEPALI KITCHEN INC.                      both
# 1    10001  New York        La mexican inc                      both
# 2    10001  New York   Wok 43rd Street LLC                  sidewalk
# 3    10002  New York  521 Restaurant Corp.                  sidewalk
# 4    10002  New York  521 Restaurant Corp.                  sidewalk
#
#   approved_for_sidewalk_seating approved_for_roadway_seating  \
# 0                           yes                          yes
# 1                           yes                          yes
# 2                           yes                           no
# 3                           yes                           no
# 4                           yes                           no
#
#    sidewalk_dimensions_area  roadway_dimensions_area qualify_alcohol  \
# 0                     357.0                    168.0             yes
# 1                     180.0                    168.0             yes
# 2                     504.0                    428.0              no
# 3                     304.0                    200.0              no
# 4                     304.0                    200.0              no
#
#   sla_license_type inspection_grade
# 0               OP                A
# 1               OP                A
# 2               OP                A
# 3               OP                A
# 4               OP                A

# %%
final_data_1_2 = pd.concat([mrg_data_1_final ,mrg_data_2_final ,mrg_data_3_final ],axis=0)

# %%
final_data_1_2
# Out:
#       zipcode    county          legal_business_name  \
# 0       10002  New York  EAST SIDE DAIRY MAKOLET INC
# 1       10002  New York                MAZEL TOV INC
# 2       10002  New York  NEW HONG FA SEA PRODUCE INC
# 3       10003  New York               CVS ALBANY LLC
# 4       10010  New York  SILVER STAR ENTERPRISES INC
# ...       ...       ...                          ...
# 3433    11804    Nassau         Jeun Ju Sik Dang Inc
# 3434    11934   Suffolk                  DOMIZIA INC
# 3435    11940   Suffolk         ACP 111 ST REST CORP
# 3436    11951   Suffolk         Cafe y Algo Mas, Inc
# 3437    11951   Suffolk         Cafe y Algo Mas, Inc
#
#      seating_interest_sidewalk approved_for_sidewalk_seating  \
# 0                     sidewalk                           yes
# 1                     sidewalk                           yes
# 2                      roadway                            no
# 3                         both                           yes
# 4                         both                           yes
# ...                        ...                           ...
# 3433                      both                           yes
# 3434                  sidewalk                           yes
# 3435                   roadway                            no
# 3436                  sidewalk                           yes
# 3437                      both                           yes
#
#      approved_for_roadway_seating  sidewalk_dimensions_area  \
# 0                              no                     304.0
# 1                              no                     304.0
# 2                             yes                     240.0
# 3                             yes                     126.0
# 4                             yes                    1035.0
# ...                           ...                       ...
# 3433                          yes                     120.0
# 3434                           no                     500.0
# 3435                          yes                     284.5
# 3436                           no                     112.0
# 3437                          yes                     112.0
#
#       roadway_dimensions_area qualify_alcohol sla_license_type  \
# 0                       200.0              no               OP
# 1                       200.0              no               OP
# 2                       160.0             yes               OP
# 3                       280.0             yes               OP
# 4                       280.0             yes               OP
# ...                       ...             ...              ...
# 3433                    160.0             yes               RW
# 3434                    480.0              no               OP
# 3435                    464.0             yes               OP
# 3436                    120.0              no               OP
# 3437                    128.0              no               OP
#
#      inspection_grade
# 0                   A
# 1                   A
# 2                   A
# 3                   A
# 4                   B
# ...               ...
# 3433                A
# 3434                A
# 3435                A
# 3436                A
# 3437                A
#
# [829 rows x 11 columns]

# %%
final_data_1_2.duplicated().sum()
# Out:
# 33

# %%
final_data_1_2= final_data_1_2.drop_duplicates()

# %%
final_data_1_2
# Out:
#       zipcode    county          legal_business_name  \
# 0       10002  New York  EAST SIDE DAIRY MAKOLET INC
# 1       10002  New York                MAZEL TOV INC
# 2       10002  New York  NEW HONG FA SEA PRODUCE INC
# 3       10003  New York               CVS ALBANY LLC
# 4       10010  New York  SILVER STAR ENTERPRISES INC
# ...       ...       ...                          ...
# 3433    11804    Nassau         Jeun Ju Sik Dang Inc
# 3434    11934   Suffolk                  DOMIZIA INC
# 3435    11940   Suffolk         ACP 111 ST REST CORP
# 3436    11951   Suffolk         Cafe y Algo Mas, Inc
# 3437    11951   Suffolk         Cafe y Algo Mas, Inc
#
#      seating_interest_sidewalk approved_for_sidewalk_seating  \
# 0                     sidewalk                           yes
# 1                     sidewalk                           yes
# 2                      roadway                            no
# 3                         both                           yes
# 4                         both                           yes
# ...                        ...                           ...
# 3433                      both                           yes
# 3434                  sidewalk                           yes
# 3435                   roadway                            no
# 3436                  sidewalk                           yes
# 3437                      both                           yes
#
#      approved_for_roadway_seating  sidewalk_dimensions_area  \
# 0                              no                     304.0
# 1                              no                     304.0
# 2                             yes                     240.0
# 3                             yes                     126.0
# 4                             yes                    1035.0
# ...                           ...                       ...
# 3433                          yes                     120.0
# 3434                           no                     500.0
# 3435                          yes                     284.5
# 3436                           no                     112.0
# 3437                          yes                     112.0
#
#       roadway_dimensions_area qualify_alcohol sla_license_type  \
# 0                       200.0              no               OP
# 1                       200.0              no               OP
# 2                       160.0             yes               OP
# 3                       280.0             yes               OP
# 4                       280.0             yes               OP
# ...                       ...             ...              ...
# 3433                    160.0             yes               RW
# 3434                    480.0              no               OP
# 3435                    464.0             yes               OP
# 3436                    120.0              no               OP
# 3437                    128.0              no               OP
#
#      inspection_grade
# 0                   A
# 1                   A
# 2                   A
# 3                   A
# 4                   B
# ...               ...
# 3433                A
# 3434                A
# 3435                A
# 3436                A
# 3437                A
#
# [796 rows x 11 columns]

# %%
final_data_1_2.to_csv(r'R:\project\final_data_1_2.csv', index=False)

# %%
sns.set_style("whitegrid")
sns.catplot(x="county", y="sidewalk_dimensions_area", hue="inspection_grade", kind="swarm",height=5,aspect=2.5, data=final_data_1_2)
sns.set_context("poster")
# Out:
# C:\Users\AMD\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\AMD\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\AMD\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\AMD\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 58.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\AMD\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\AMD\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#fig_dims = (12, 4)
#fig, ax = plt.subplots(figsize=fig_dims)
sns.set(font_scale=1.25)
sns.set_style("whitegrid")
sns.catplot(x="county", y="sidewalk_dimensions_area", hue="inspection_grade", 
            kind="violin",aspect=2,height=5, data=final_data_1_2)
# Largest Context:
#sns.set_context("poster")

# %%
sns.set(font_scale=1.25)
sns.set_style("whitegrid")
sns.catplot(x="county", y="roadway_dimensions_area", hue="inspection_grade", 
            kind="violin",aspect=2,height=5, data=final_data_1_2)

# %%
sns.set(font_scale=1.25)
sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(11,8)})
sns.stripplot(x="county", y="sidewalk_dimensions_area", data=final_data_1_2)
# Out:
# <AxesSubplot:xlabel='county', ylabel='sidewalk_dimensions_area'>

# %%
sns.set(font_scale=1.25)
sns.catplot( x="inspection_grade", y="sidewalk_dimensions_area", height=5,aspect=1.5,
            kind="boxen", data=final_data_1_2)

# %%
sns.set_style("darkgrid")
sns.stripplot(x="inspection_grade", y="sidewalk_dimensions_area", data=final_data_1_2)
# Out:
# <AxesSubplot:xlabel='inspection_grade', ylabel='sidewalk_dimensions_area'>

# %%
sns.set(font_scale=1.25)
sns.set(rc={'figure.figsize':(5,5)})
sns.countplot(x ='inspection_grade',palette="mako",saturation=1, edgecolor=(0,0,0),
                  linewidth=2, data = final_data_1_2)
# Out:
# <AxesSubplot:xlabel='inspection_grade', ylabel='count'>

# %%
# count plot on two categorical variable
#sns.countplot(y ='county', hue = "inspection_grade", data = final_data_1_2)

# %%
# count plot on two categorical variable
sns.set(font_scale=1)
sns.set_style("darkgrid",{"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x ='county', hue = "inspection_grade",palette="mako",saturation=1, edgecolor=(0,0,0),
                  linewidth=2, data = final_data_1_2)
# Out:
# <AxesSubplot:xlabel='county', ylabel='count'>

# %%
sns.set(font_scale=1.25)
sns.set_style("darkgrid",{"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(5,5)})
sns.countplot(x ='inspection_grade', hue = "qualify_alcohol", palette="mako",saturation=1, edgecolor=(0,0,0),
                  linewidth=2, data = final_data_1_2)
#darkgrid
# Out:
# <AxesSubplot:xlabel='inspection_grade', ylabel='count'>

# %%
sns.set(font_scale=1.25)
sns.set_style("darkgrid",{"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(5,5)})
sns.countplot(x ='inspection_grade', hue = "approved_for_sidewalk_seating", palette="mako",saturation=1, edgecolor=(0,0,0),
                  linewidth=2, data = final_data_1_2)
#darkgrid
#sns.pointplot(final_data_1_2['humidity'], final_data_1_2['temperature'], hue=final_data_1_2['weather_type'])
# Out:
# <AxesSubplot:xlabel='inspection_grade', ylabel='count'>

# %%
sns.set(font_scale=1.25)
sns.set_style("darkgrid",{"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(5,5)})
sns.countplot(x ='inspection_grade', hue = "approved_for_roadway_seating", palette="mako",saturation=1, edgecolor=(0,0,0),
                  linewidth=2, data = final_data_1_2)
# Out:
# <AxesSubplot:xlabel='inspection_grade', ylabel='count'>

# %%
sns.set(font_scale=1.25)
sns.set_style("darkgrid",{"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(10,8)})
sns.countplot(x ='sla_license_type', hue = "inspection_grade", palette="mako",saturation=1, edgecolor=(0,0,0),
                  linewidth=2, data = final_data_1_2)
#darkgrid
#darkgrid
# Out:
# <AxesSubplot:xlabel='sla_license_type', ylabel='count'>

# %%
sns.catplot(data= final_data_1_2,x='approved_for_sidewalk_seating',y='sidewalk_dimensions_area', palette="mako",kind='point',hue="inspection_grade", join=False,capsize=0.2)

# %%
sns.catplot(data= final_data_1_2,x='approved_for_roadway_seating',y='roadway_dimensions_area',palette="mako",kind='point',hue="inspection_grade", join=False,capsize=0.2)
